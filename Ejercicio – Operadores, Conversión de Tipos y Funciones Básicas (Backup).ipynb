# %% [markdown]
# ## Calculadora Avanzada en Python
#
# ### Alumno: Samuel Iván Gamboa Vázquez

# %%
import numpy as geek # Importando biblioteca para funciones de arrays
import math
import numpy as np
my_option = 0 # Limpiando mi variable de selección para correr mi calculadora
while my_option != 6:
    print("""
        Selecciona una opción:

        1) Sumar
        2) Restar
        3) Multiplicar
        4) Dividir
        5) Elevar a la potencia
        6) Salir
        """)
    my_option = int(input("Elige una opción: ") )

    if my_option < 1 or my_option > 6:
        print ("Opción inválida.")
    else:

        my_option2 = 0 # Limpiando mi variable de selección para correr mi calculadora
        print("""
            Selecciona una opción:

            1) Listas
            2) Sets
            3) Diccionarios
            4) Regresar
            """)
        my_option2 = int(input("Elige una opción: ") )

        if my_option2 == 1:
            # Agregar valor de Lista
            user_input = input("Agrega 5 valores numéricos separados por un espacio: ")

            my_list = list(float(num) for num in user_input.split())

            if len(my_list) == 5:
                print(my_list)
                print("El tipo de variable introducida es: ", type(my_list))
            else:
                print("Lista no válida")

        if my_option2 == 2:
            # Agregar valor de Set

            user_input = input("Agrega 5 valores numéricos separados por un espacio: ")

            my_set = set(float(num) for num in user_input.split())

            if len(my_set) == 5:
                print(my_set)
                print("El tipo de variable introducida es: ", type(my_set))
            else:
                print("Set no válido")

        if my_option2 == 3:
                # Agregar valor de Diccionario
            my_dictionary = {}

            for num in range(5):
                position = str(num)
                user_input = float(input("Agrega un valor numérico hasta llegar agregar 5: "))
                my_dictionary[position] = user_input
            if len(my_dictionary) == 5:
                print(my_dictionary)
                print("El tipo de variable introducida es: ", type(my_dictionary))
            else:
                print("Diccionario no válido")

        if my_option2 == 4 or my_option2 < 1:
                quit()
        else:
            if my_option == 1:
                print("\nOperación Seleccionada: Suma")
                my_input = float(input("Ingresa el número a sumar: "))
                if my_option2 == 1:
                    print("Valores de entrada: ",my_list)
                    my_list2 = []
                    for item in my_list:
                        my_list2.append(item + my_input)
                    print("Resultado: ",my_list2)
                elif my_option2 == 2:
                    print("Valores de entrada: ",my_set)
                    my_set2 = set()
                    for item in my_set:
                        my_set2.add(item + my_input)
                    print("Resultado: ",my_set2)
                else:
                    print("Valores de entrada: ",my_dictionary)
                    my_dictionary2 = {}
                    for position, user_input in my_dictionary.items():
                        my_dictionary2val = user_input + my_input
                        my_dictionary2[position] = my_dictionary2val
                    print("Resultado: ",my_dictionary2)
            if my_option == 2:
                print("\nOperación Seleccionada: Resta")
                my_input = float(input("Ingresa el número a restar: "))
                if my_option2 == 1:
                    print("Valores de entrada: ",my_list)
                    my_list2 = []
                    for item in my_list:
                        my_list2.append(item - my_input)
                    print("Resultado: ",my_list2)
                elif my_option2 == 2:
                    print("Valores de entrada: ",my_set)
                    my_set2 = set()
                    for item in my_set:
                        my_set2.add(item - my_input)
                    print("Resultado: ",my_set2)
                else:
                    print("Valores de entrada: ",my_dictionary)
                    my_dictionary2 = {}
                    for position, user_input in my_dictionary.items():
                        my_dictionary2val = user_input - my_input
                        my_dictionary2[position] = my_dictionary2val
                    print("Resultado: ",my_dictionary2)
            if my_option == 3:
                print("\nOperación Seleccionada: Multiplicación")
                my_input = float(input("Ingresa el número a multiplicar: "))
                if my_option2 == 1:
                    print("Valores de entrada: ",my_list)
                    my_list2 = []
                    for item in my_list:
                        my_list2.append(item * my_input)
                    print("Resultado: ",my_list2)
                elif my_option2 == 2:
                    print("Valores de entrada: ",my_set)
                    my_set2 = set()
                    for item in my_set:
                        my_set2.add(item * my_input)
                    print("Resultado: ",my_set2)
                else:
                    print("Valores de entrada: ",my_dictionary)
                    my_dictionary2 = {}
                    for position, user_input in my_dictionary.items():
                        my_dictionary2val = user_input * my_input
                        my_dictionary2[position] = my_dictionary2val
                    print("Resultado: ",my_dictionary2)
            if my_option == 4:
                print("\nOperación Seleccionada: División")
                my_input = float(input("Ingresa el número a dividir: "))
                if my_option2 == 1:
                    print("Valores de entrada: ",my_list)
                    my_list2 = []
                    for item in my_list:
                        my_list2.append(round(item / my_input,4))
                    print("Resultado: ",my_list2)
                elif my_option2 == 2:
                    print("Valores de entrada: ",my_set)
                    my_set2 = set()
                    for item in my_set:
                        my_set2.add(round(item / my_input,4))
                    print("Resultado: ",my_set2)
                else:
                    print("Valores de entrada: ",my_dictionary)
                    my_dictionary2 = {}
                    for position, user_input in my_dictionary.items():
                        my_dictionary2val = round(user_input / my_input,4)
                        my_dictionary2[position] = my_dictionary2val
                    print("Resultado: ",my_dictionary2)
            if my_option == 5:
                print("\nOperación Seleccionada: Elevar al exponente")
                my_input = float(input("Ingresa el número por el cual elevar: "))
                if my_option2 == 1:
                    print("Valores de entrada: ",my_list)
                    my_list2 = []
                    for item in my_list:
                        my_list2.append(round(item ** my_input,4))
                    print("Resultado: ",my_list2)
                elif my_option2 == 2:
                    print("Valores de entrada: ",my_set)
                    my_set2 = set()
                    for item in my_set:
                        my_set2.add(round(item ** my_input,4))
                    print("Resultado: ",my_set2)
                else:
                    print("Valores de entrada: ",my_dictionary)
                    my_dictionary2 = {}
                    for position, user_input in my_dictionary.items():
                        my_dictionary2val = round(user_input ** my_input,4)
                        my_dictionary2[position] = my_dictionary2val
                    print("Resultado: ",my_dictionary2)

# %%
# Agregar valor de Lista
user_input = input("Agrega 5 valores numéricos separados por un espacio para tu primera lista: ")

my_list = list(float(num) for num in user_input.split())

if len(my_list) == 5:
    print(my_list)
    print("El tipo de variable introducida es: ", type(my_list))
else:
    print("Lista no válida")
    
user_input = input("Agrega 5 valores numéricos separados por un espacio para tu segunda lista: ")

my_list2 = list(float(num) for num in user_input.split())

if len(my_list2) == 5:
    print(my_list2)
    print("El tipo de variable introducida es: ", type(my_list2))
else:
    print("Lista no válida")
# Out:
# Agrega 5 valores numéricos separados por un espacio para tu primera lista:  1 4 7 8 9
# [1.0, 4.0, 7.0, 8.0, 9.0]
# El tipo de variable introducida es:  <class 'list'>
# Agrega 5 valores numéricos separados por un espacio para tu segunda lista: 6 8 7 5 9
# [6.0, 8.0, 7.0, 5.0, 9.0]
# El tipo de variable introducida es:  <class 'list'>
# 64.0

# %%
# Agregar valor de Set

user_input = input("Agrega 5 valores numéricos separados por un espacio para tu primer set: ")

my_set = set(float(num) for num in user_input.split())

if len(my_set) == 5:
    print(my_set)
    print("El tipo de variable introducida es: ", type(my_set))
else:
    print("Set no válido")
    
user_input = input("Agrega 5 valores numéricos separados por un espacio para tu segundo set: ")

my_set2 = set(float(num) for num in user_input.split())

if len(my_set2) == 5:
    print(my_set2)
    print("El tipo de variable introducida es: ", type(my_set2))
else:
    print("Set no válido")
# Out:
# Agrega 5 valores numéricos separados por un espacio para tu primer set: 1 4 7 8 9
# {1.0, 4.0, 7.0, 8.0, 9.0}
# El tipo de variable introducida es:  <class 'set'>
# Agrega 5 valores numéricos separados por un espacio para tu segundo set: 1 5 4 8 7
# {1.0, 4.0, 5.0, 7.0, 8.0}
# El tipo de variable introducida es:  <class 'set'>

# %%
# Agregar valor de Diccionario
my_dictionary = {}
my_dictionary_2 = {}

for num in range(5):
    position = str(num)
    user_input = input("Agrega un valor numérico hasta llegar agregar 5 (Primer diccionario): ")
    my_dictionary[position] = user_input
if len(my_dictionary) == 5:
    print(my_dictionary)
    print("El tipo de variable introducida es: ", type(my_dictionary))
else:
    print("Diccionario no válido")
    
for num in range(5):
    position = str(num)
    user_input = input("Agrega un valor numérico hasta llegar agregar 5 (Segundo diccionario): ")
    my_dictionary_2[position] = user_input
if len(my_dictionary_2) == 5:
    print(my_dictionary_2)
    print("El tipo de variable introducida es: ", type(my_dictionary_2))
else:
    print("Diccionario no válido")
# Out:
# Agrega un valor numérico hasta llegar agregar cinco instancias: 1
# Agrega un valor numérico hasta llegar agregar cinco instancias: 4
# Agrega un valor numérico hasta llegar agregar cinco instancias: 7
# Agrega un valor numérico hasta llegar agregar cinco instancias: 8
# Agrega un valor numérico hasta llegar agregar cinco instancias: 6
# {'0': '1', '1': '4', '2': '7', '3': '8', '4': '6'}
# El tipo de variable introducida es:  <class 'dict'>
# Agrega un valor numérico hasta llegar agregar cinco instancias: 5
# Agrega un valor numérico hasta llegar agregar cinco instancias: 4
# Agrega un valor numérico hasta llegar agregar cinco instancias: 8
# Agrega un valor numérico hasta llegar agregar cinco instancias: 9
# Agrega un valor numérico hasta llegar agregar cinco instancias: 4
# {'0': '5', '1': '4', '2': '8', '3': '9', '4': '4'}
# El tipo de variable introducida es:  <class 'dict'>

# %%
import numpy as geek # Importando biblioteca para funciones de arrays
my_option = 0 # Limpiando mi variable de selección para correr mi calculadora
print("""
    Selecciona una opción:

    1) Sumar
    2) Restar
    3) Multiplicar
    4) Dividir
    5) Elevar a la potencia
    6) Salir
    """)
my_option = int(input("Elige una opción: ") )

if my_option == 6 or my_option < 1:
    quit()
else:

    my_option2 = 0 # Limpiando mi variable de selección para correr mi calculadora
    print("""
        Selecciona una opción:

        1) Listas
        2) Sets
        3) Diccionarios
        4) Salir
        """)
    my_option2 = int(input("Elige una opción: ") )

    if my_option2 == 1:
        # Agregar valor de Lista
        user_input = input("Agrega 5 valores numéricos separados por un espacio para tu primera lista: ")

        my_list = list(float(num) for num in user_input.split())

        if len(my_list) == 5:
            print(my_list)
            print("El tipo de variable introducida es: ", type(my_list))
        else:
            print("Lista no válida")

        user_input = input("Agrega 5 valores numéricos separados por un espacio para tu segunda lista: ")

        my_list2 = list(float(num) for num in user_input.split())

        if len(my_list2) == 5:
            print(my_list2)
            print("El tipo de variable introducida es: ", type(my_list2))
        else:
            print("Lista no válida")

    if my_option2 == 2:
        # Agregar valor de Set

        user_input = input("Agrega 5 valores numéricos separados por un espacio para tu primer set: ")

        my_set = set(float(num) for num in user_input.split())

        if len(my_set) == 5:
            print(my_set)
            print("El tipo de variable introducida es: ", type(my_set))
        else:
            print("Set no válido")

        user_input = input("Agrega 5 valores numéricos separados por un espacio para tu segundo set: ")

        my_set2 = set(float(num) for num in user_input.split())

        if len(my_set2) == 5:
            print(my_set2)
            print("El tipo de variable introducida es: ", type(my_set2))
        else:
            print("Set no válido")

    if my_option2 == 3:
            # Agregar valor de Diccionario
        my_dictionary = {}
        my_dictionary_2 = {}

        for num in range(5):
            position = str(num)
            user_input = input("Agrega un valor numérico hasta llegar agregar 5 (Primer diccionario): ")
            my_dictionary[position] = user_input
        if len(my_dictionary) == 5:
            print(my_dictionary)
            print("El tipo de variable introducida es: ", type(my_dictionary))
        else:
            print("Diccionario no válido")

        for num in range(5):
            position = str(num)
            user_input = input("Agrega un valor numérico hasta llegar agregar 5 (Segundo diccionario): ")
            my_dictionary_2[position] = user_input
        if len(my_dictionary_2) == 5:
            print(my_dictionary_2)
            print("El tipo de variable introducida es: ", type(my_dictionary_2))
        else:
            print("Diccionario no válido")

    if my_option2 == 4 or my_option2 < 1:
            quit()
    else:
        if my_option == 1:
            print("\nOperación Seleccionada: Suma")
            if my_option2 ==1:
                print("Valor de entrada 1: ",my_list)
                print("Valor de entrada 2: ",my_list2)
                my_list3 = sum(my_list+my_list2)
                print("Resultado: ",my_list3)
            elif my_option2 == 2:
                print("Valor de entrada 1: ",my_set)
                print("Valor de entrada 2: ",my_set2)
                my_set3 = sum(my_set+my_set2)
                print("Resultado: ",my_set3)

# %%
a={
    5: "Python",
  10: "sum",
  15: "function"
}

#using Python sum function without start parameter
Sum = sum(a)
print(Sum)

#using Python sum function with start parameter
Sum = sum(a, 20)
print(Sum)
# Out:
# 30
# 50

# %%
print(my_dictionary)
# Out:
# {'0': 1, '1': 5, '2': 4, '3': 7, '4': 8}

# %%
print(a)
# Out:
# {5: 'Python', 10: 'sum', 15: 'function'}

# %%
import numpy as geek # Importando biblioteca para funciones de arrays
import math
my_option = 0 # Limpiando mi variable de selección para correr mi calculadora
print("""
    Selecciona una opción:

    1) Sumar
    2) Restar
    3) Multiplicar
    4) Dividir
    5) Elevar a la potencia
    6) Salir
    """)
my_option = int(input("Elige una opción: ") )

if my_option == 6 or my_option < 1:
    quit()
else:

    my_option2 = 0 # Limpiando mi variable de selección para correr mi calculadora
    print("""
        Selecciona una opción:

        1) Listas
        2) Sets
        3) Diccionarios
        4) Salir
        """)
    my_option2 = int(input("Elige una opción: ") )

    if my_option2 == 1:
        # Agregar valor de Lista
        user_input = input("Agrega 5 valores numéricos separados por un espacio: ")

        my_list = list(float(num) for num in user_input.split())

        if len(my_list) == 5:
            print(my_list)
            print("El tipo de variable introducida es: ", type(my_list))
        else:
            print("Lista no válida")

    if my_option2 == 2:
        # Agregar valor de Set

        user_input = input("Agrega 5 valores numéricos separados por un espacio: ")

        my_set = set(float(num) for num in user_input.split())

        if len(my_set) == 5:
            print(my_set)
            print("El tipo de variable introducida es: ", type(my_set))
        else:
            print("Set no válido")

    if my_option2 == 3:
            # Agregar valor de Diccionario
        my_dictionary = {}

        for num in range(5):
            position = str(num)
            user_input = float(input("Agrega un valor numérico hasta llegar agregar 5: "))
            my_dictionary[position] = user_input
        if len(my_dictionary) == 5:
            print(my_dictionary)
            print("El tipo de variable introducida es: ", type(my_dictionary))
        else:
            print("Diccionario no válido")

    if my_option2 == 4 or my_option2 < 1:
            quit()
    else:
        if my_option == 1:
            print("\nOperación Seleccionada: Suma")
            if my_option2 == 1:
                print("Valores de entrada: ",my_list)
                my_list2 = sum(my_list)
                print("Resultado: ",my_list2)
            elif my_option2 == 2:
                print("Valores de entrada: ",my_set)
                my_set2 = sum(my_set)
                print("Resultado: ",my_set2)
            else:
                print("Valores de entrada: ",my_dictionary)
                my_dictionary2 = sum(my_dictionary.values())
                print("Resultado: ",my_dictionary2)
        if my_option == 2:
            print("\nOperación Seleccionada: Resta")
            if my_option2 == 1:
                print("Valores de entrada: ",my_list)
                my_list = [item * -1 for item in my_list]
                my_list2 = sum(my_list)
                print("Resultado: ",my_list2)
            elif my_option2 == 2:
                print("Valores de entrada: ",my_set)
                my_set = [item * -1 for item in my_set]
                my_set2 = sum(my_set)
                print("Resultado: ",my_set2)
            else:
                print("Valores de entrada: ",my_dictionary)
                my_dictionary.update((x, y*-1) for x, y in my_dictionary.items())
                my_dictionary2 = sum(my_dictionary.values())
                print("Resultado: ",my_dictionary2)
        if my_option == 3:
            print("\nOperación Seleccionada: Multiplicación")
            if my_option2 == 1:
                print("Valores de entrada: ",my_list)
                my_list2 = math.prod(my_list)
                print("Resultado: ",my_list2)
            elif my_option2 == 2:
                print("Valores de entrada: ",my_set)
                my_set2 = math.prod(my_set)
                print("Resultado: ",my_set2)
            else:
                print("Valores de entrada: ",my_dictionary)
                my_dictionary2 = math.prod(my_dictionary.values())
                print("Resultado: ",my_dictionary2)

# %%
# Step 1: Get the input element from the user
input_element = float(input("Enter the input element: "))  # You can change the data type as needed

# Step 2: Define your set of values (or use a list if order matters)
my_set = {1, 2, 3, 4, 5}

# Step 3: Create a new set or list to store the results
result_set = set()

# Step 4: Iterate through the set of values and add the input element to each value
for value in my_set:
    result_set.add(value + input_element)

# Alternatively, you can use a list comprehension for a more concise solution:
# result_list = [value + input_element for value in my_set]

# Step 5: Print or use the results
print("Original set of values:", my_set)
print("Resulting set of values:", result_set)
# Out:
# Enter the input element: 5
# Original set of values: {1, 2, 3, 4, 5}
# Resulting set of values: {6.0, 7.0, 8.0, 9.0, 10.0}

# %%
# Get the input element from the user
input_element = float(input("Enter the input element: "))  # Convert to float assuming it's a number

# Define your dictionary of values (you can change this to your specific dictionary)
your_dictionary_of_values = {"value1": 10, "value2": 20, "value3": 30, "value4": 40}

# Create a new dictionary to store the results
results = {}

# Iterate through the dictionary and add the input element to each value
for key, value in your_dictionary_of_values.items():
    result = input_element + value
    results[key] = result

# Print the results
print("Input element:", input_element)
print("Results after adding the input element to each value in the dictionary:")
for key, result in results.items():
    print(f"{key}: {result}")
# Out:
# Enter the input element: 1
# Input element: 1.0
# Results after adding the input element to each value in the dictionary:
# value1: 11.0
# value2: 21.0
# value3: 31.0
# value4: 41.0
